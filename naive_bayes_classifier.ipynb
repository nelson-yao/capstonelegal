# %% [markdown]
# ### Install and import libraries

# %%
import pickle
import pandas as pd

import nltk
# nltk.download('punkt')      # uncomment to download punkt

# !pip install -U textblob    # uncomment to install textblob
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier

# %% [markdown]
# ## Read Pickeled Data
# This file reads and processes data that has previously been pickeled by Parse_opp_115

# %%
# Choose one of several data files
with open('Data/parsed-annotation-0.5.pk', 'rb') as pfile:
    data = pickle.load(pfile)
    pfile.close()

# %% [markdown]
# ### Data structure
# `data[site][category][topic] =` pandas dataframe

# %% [markdown]
# ### Sites, Categories, and Topics
# Print out all sites, categories, and topics

# %%
sites = set()
categories = set()
topics = set()
values = set()

for site in data:
    sites.add(site)
    for category in data[site]:
        categories.add(category)
        for topic in data[site][category]:
            topics.add(topic)
            for row in data[site][category][topic].iterrows():
                index, rowdata = row
                values.add(rowdata["value"])

                    
print "Sites [{}]: ".format(len(sites)) + "; ".join(sorted(sites))
print
print "Categories [{}]: ".format(len(categories)) + "; ".join(sorted(categories))
print
print "Topics [{}]: ".format(len(topics)) + "; ".join(sorted(topics))
print
print "Values [{}]: ".format(len(values)) + "; ".join(sorted(values))
# Out:
# Sites [115]: abcnews.com; abita.com; acbj.com; adweek.com; allstate.com; amazon.com; aol.com; archives.gov; austincc.edu; bankofamerica.com; barnesandnoble.com; boardgamegeek.com; buffalowildwings.com; cariboucoffee.com; cbsinteractive.com; chasepaymentech.com; cincymuseum.org; citizen.org; coffeereview.com; communitycoffee.com; dailyillini.com; dailynews.com; dairyqueen.com; dcccd.edu; disinfo.com; dogbreedinfo.com; earthkam.org; eatchicken.com; education.jlab.org; enthusiastnetwork.com; esquire.com; everydayhealth.com; foodallergy.org; fool.com; fortune.com; foxsports.com; fredericknewspost.com; freep.com; gamestop.com; gawker.com; geocaching.com; google.com; gwdocs.com; highgearmedia.com; honda.com; ifsa-butler.org; imdb.com; instagram.com; internetbrands.com; ironhorsevineyards.com; jibjab.com; kaleidahealth.org; kraftrecipes.com; latinpost.com; lids.com; liquor.com; lodgemfg.com; lynda.com; meredith.com; miaminewtimes.com; military.com; minecraft.gamepedia.com; mlb.mlb.com; mohegansun.com; msn.com; naturalnews.com; nbcuniversal.com; neworleansonline.com; newsbusters.org; nytimes.com; ocregister.com; opensecrets.org; pbs.org; playstation.com; post-gazette.com; randomhouse.com; reddit.com; redorbit.com; reference.com; restaurantnews.com; rockstargames.com; sci-news.com; sciencemag.org; sheknows.com; si.edu; sidearmsports.com; sltrib.com; solarviews.com; sports-reference.com; steampowered.com; stlouisfed.org; style.com; tangeroutlet.com; taylorswift.com; ted.com; tgifridays.com; theatlantic.com; thefreedictionary.com; thehill.com; ticketmaster.com; timeinc.com; tulsaworld.com; uh.edu; uptodate.com; usa.gov; vikings.com; voxmedia.com; walmart.com; washingtonian.com; washingtonpost.com; wnep.com; wsmv.com; www.loc.gov; yahoo.com; zacks.com
#
# Categories [10]: Data Retention; Data Security; Do Not Track; First Party Collection/Use; International and Specific Audiences; Other; Policy Change; Third Party Sharing/Collection; User Access, Edit and Deletion; User Choice/Control
#
# Topics [22]: Access Scope; Access Type; Action First-Party; Action Third Party; Audience Type; Change Type; Choice Scope; Choice Type; Collection Mode; Do Not Track policy; Does/Does Not; Identifiability; Notification Type; Other Type; Personal Information Type; Purpose; Retention Period; Retention Purpose; Security Measure; Third Party Entity; User Choice; User Type
#
# Values [109]: Additional service/feature; Advertising; Aggregated or anonymized; Analytics/Research; Basic service/feature; Both; Browser/device privacy controls; Californians; Children; Citizens from other countries; Collect from user on other websites; Collect in mobile app; Collect on first party website/app; Collect on mobile website; Collect on website; Collection; Computer information; Contact; Cookies and tracking elements; Data access limitation; Deactivate account; Delete account (full); Delete account (partial); Demographic; Does; Does Not; Dont use service/feature; Edit information; Europeans; Explicit; Export; Financial; First party collection; First party use; First-party privacy controls; General notice in privacy policy; General notice on website; Generic; Generic personal information; Health; Honored; IP address and device IDs; Identifiable; Implicit; In case of merger or acquisition; Indefinitely; Introductory/Generic; Legal requirement; Limited; Location; Marketing; Mentioned, but unclear if honored; Merger/Acquisition; Named third party; No notification; Non-privacy relevant change; None; Not honored; Opt-in; Opt-out; Opt-out link; Opt-out via contacting company; Other; Other data about user; Other part of company/affiliate; Other users; Perform service; Personal identifier; Personal notice; Personalization/Customization; Practice not covered; Privacy contact information; Privacy relevant change; Privacy review/audit; Privacy training; Privacy/Security program; Profile data; Public; Receive from other parts of company/affiliates; Receive from other service/third-party (named); Receive from other service/third-party (unnamed); Receive/Shared with; Secure data storage; Secure data transfer; Secure user authentication; See; Service Operation and Security; Service operation and security; Social media data; Stated Period; Survey data; Third party sharing/collection; Third party use; Third-party privacy controls; Track on first party website/app; Track user on other websites; Transactional data; Unnamed third party; Unspecified; Use; User Profile; User account data; User online activities; User participation; User profile; User with account; User without account; View; not-selected

# %% [markdown]
# ### Convert to a Pandas DataFrame

# %%
df = pd.DataFrame(data)
df['abcnews.com']['Data Retention']['Personal Information Type']
# Out:
#    endIndexInSegment  section          selectedText  startIndexInSegment  \
# 0                599       26  personal information                  579
# 1                599       26  personal information                  579
#
#                           value
# 0  Generic personal information
# 1  Generic personal information

# %%
df['abcnews.com']['Data Retention']['Personal Information Type']['value'][0]
# Out:
# 'Generic personal information'

# %%
df['usa.gov']['Data Retention'].keys()
# Out:
# ['Retention Period', 'Retention Purpose', 'Personal Information Type']

# %%
df['usa.gov']['Data Retention']['Personal Information Type']
# Out:
#    endIndexInSegment  section  \
# 0                172        3
# 1                217        3
# 2                346        3
# 3                388        3
# 4                 -1        6
#
#                                         selectedText  startIndexInSegment  \
# 0                      the Internet protocol address                  143
# 1                                      date and time                  204
# 2  the name of the web site from which you linked...                  219
# 3              the browser and operating system used                  351
# 4                                                NaN                   -1
#
#                        value
# 0  IP address and device IDs
# 1                      Other
# 2     User online activities
# 3       Computer information
# 4                Unspecified

# %% [markdown]
# ### Problem with data conversion, or inherent in the data?
# Why do the data contain so many "NaN" values?

# %%
df['abcnews.com']['First Party Collection/Use']['Collection Mode']
# Out:
#     endIndexInSegment  section  \
# 0                 126        4
# 1                  -1        4
# 2                  -1        4
# 3                  -1        4
# 4                  -1        4
# 5                  46        5
# 6                  46        5
# 7                  46        5
# 8                 195        5
# 9                 195        5
# 10                 45        6
# 11                 45        6
# 12                 45        6
# 13                115        6
# 14                 45        6
# 15                 45        6
# 16                 45        6
# 17                 45        6
# 18                115        6
# 19                115        6
# 20                 33        7
# 21                 33        7
# 22                 33        7
# 23                 33        7
# 24                179        8
# 25                138        8
# 26                196        8
# 27                 39        9
# 28                 33        9
# 29                 33        9
# ..                ...      ...
# 65                100       13
# 66                 -1       13
# 67                 20       13
# 68                 20       13
# 69                 -1       13
# 70                100       13
# 71                100       13
# 72                142       14
# 73                112       14
# 74                143       14
# 75                142       14
# 76                 -1       15
# 77                 18       15
# 78                 18       15
# 79                 18       15
# 80                 18       15
# 81                 18       15
# 82                 -1       15
# 83                 -1       15
# 84                 -1       15
# 85                 -1       15
# 86                 -1       15
# 87                 -1       19
# 88                 -1       20
# 89                 -1       20
# 90                 -1       21
# 91                 -1       23
# 92                433       37
# 93                 -1       37
# 94                252       42
#
#                                          selectedText  startIndexInSegment  \
# 0   We collect two basic types of information pers...                   64
# 1                                                 NaN                   -1
# 2                                                 NaN                   -1
# 3                                                 NaN                   -1
# 4                                                 NaN                   -1
# 5                                         you provide                   35
# 6                                             provide                   39
# 7                                             provide                   39
# 8   egistration information you provide when you c...                   11
# 9   egistration information you provide when you c...                   11
# 10                                        you provide                   34
# 11                                        you provide                   34
# 12                                        you provide                   34
# 13  you provide when you request information or pu...                   34
# 14                                        you provide                   34
# 15                                            provide                   38
# 16                                            provide                   38
# 17                                        you provide                   34
# 18  you provide when you request information or pu...                   34
# 19  you provide when you request information or pu...                   34
# 20                                        you provide                   22
# 21                                        you provide                   22
# 22                            Information you provide                   10
# 23                            Information you provide                   10
# 24                                            collect                  172
# 25  Information sent either one-to-one or within a...                   22
# 26  Information sent either one-to-one or within a...                   22
# 27                      Information you provide to us                   10
# 28                                        you provide                   22
# 29                                        you provide                   22
# ..                                                ...                  ...
# 65  We collect information through technology, suc...                   10
# 66                                                NaN                   -1
# 67                                            collect                   13
# 68                                            collect                   13
# 69                                                NaN                   -1
# 70  We collect information through technology, suc...                   10
# 71  We collect information through technology, suc...                   10
# 72  We acquire information from other trusted sour...                   10
# 73                                        ou provided                  101
# 74                        we collected automatically.                  116
# 75  We acquire information from other trusted sour...                   10
# 76                                                NaN                   -1
# 77                                                 of                   16
# 78                                                 of                   16
# 79                                                 of                   16
# 80                                                 of                   16
# 81                                                 of                   16
# 82                                                NaN                   -1
# 83                                                NaN                   -1
# 84                                                NaN                   -1
# 85                                                NaN                   -1
# 86                                                NaN                   -1
# 87                                                NaN                   -1
# 88                                                NaN                   -1
# 89                                                NaN                   -1
# 90                                                NaN                   -1
# 91                                                NaN                   -1
# 92  We may use IP addresses to collect information...                  231
# 93                                                NaN                   -1
# 94                                        you provide                  241
#
#           value
# 0   Unspecified
# 1   Unspecified
# 2   Unspecified
# 3   Unspecified
# 4   Unspecified
# 5      Explicit
# 6      Explicit
# 7      Explicit
# 8      Explicit
# 9      Explicit
# 10     Explicit
# 11     Explicit
# 12     Explicit
# 13     Explicit
# 14     Explicit
# 15     Explicit
# 16     Explicit
# 17     Explicit
# 18     Explicit
# 19     Explicit
# 20     Explicit
# 21     Explicit
# 22     Explicit
# 23     Explicit
# 24     Implicit
# 25  Unspecified
# 26     Implicit
# 27     Explicit
# 28     Explicit
# 29     Explicit
# ..          ...
# 65     Implicit
# 66  Unspecified
# 67     Implicit
# 68     Implicit
# 69  Unspecified
# 70     Implicit
# 71     Implicit
# 72     Implicit
# 73     Explicit
# 74     Implicit
# 75     Implicit
# 76  Unspecified
# 77     Implicit
# 78     Implicit
# 79     Implicit
# 80     Implicit
# 81     Implicit
# 82  Unspecified
# 83  Unspecified
# 84  Unspecified
# 85  Unspecified
# 86  Unspecified
# 87  Unspecified
# 88  Unspecified
# 89  Unspecified
# 90  Unspecified
# 91  Unspecified
# 92     Implicit
# 93  Unspecified
# 94     Explicit
#
# [95 rows x 5 columns]

# %% [markdown]
# ### Create a training data set

# %%
train = []

# sites = data.keys()[0:10]

# let's start with just 1 site
sites = ["washingtonpost.com"]

for site in sites:
    for category in data[site]:
        #print "#" * 50
        #print category
        for topic in data[site][category]:
            #print "-" * 50
            #print topic
            for row in df[site][category][topic].iterrows():
                index, rowdata = row
                # print rowdata
                try:
                    selectedText = str(rowdata["selectedText"])
                except KeyError:
                    continue
                value = rowdata["value"]

                if selectedText.lower() == "nan":
                    continue
                    
                #print "%s -> %s" % (selectedText, value)
                train.append((selectedText, value))

print len(train)
# Out:
# 772

# %% [markdown]
# ### Train a Naive Bayes Classifier

# %%
# %%time
cl = NaiveBayesClassifier(train)
# Out:
# CPU times: user 1min 59s, sys: 1.21 s, total: 2min
# Wall time: 2min

# %%
cl.classify("Your IP Address is stored")
# Out:
# 'Generic personal information'

# %%
cl.classify("We collect your email address")
# Out:
# 'Does'

# %%
cl.classify("cookies are used to track our users")
# Out:
# 'Does'

# %% [markdown]
# ### Value mapping
# We need to ignore unhelpful values or map them to something useful

# %%
useful_values = "Advertising; Children; Cookies and tracking elements; Financial; First party collection; First party use".split('; ')
print len(useful_values)
# Out:
# 6
