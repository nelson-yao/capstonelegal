# %% [markdown]
# ### Install and import libraries

# %%
import pickle
import pandas as pd

import nltk
# nltk.download('punkt')      # uncomment to download punkt

# !pip install -U textblob    # uncomment to install textblob
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier

# %% [markdown]
# ### Read Pickeled Data
# This file reads and processes data that has previously been pickeled by Parse_opp_115

# %%
# Choose one of several data files
with open('Data/parsed-annotation-0.5.pk', 'rb') as pfile:
    data = pickle.load(pfile)
    pfile.close()

# %% [markdown]
# ### Data structure
# `data[site][category][topic] =` pandas dataframe

# %% [markdown]
# ### Count the number of classifications

# %%
features = {}

for site in data:
    for category in data[site]:

        if category not in features:
            features[category] = {}

        for topic in data[site][category]:
                
            if topic not in features[category]:
                features[category][topic] = {}

            for row in data[site][category][topic].iterrows():
                index, rowdata = row
                value = rowdata["value"]
                
                if value not in features[category][topic]:
                    features[category][topic][value] = 0

                features[category][topic][value] += 1

# %% [markdown]
# ### Print out a tree of categories, topics, and values
# But only print out if we have at least 100 classifications

# %%
lines = []

for category in sorted(features):
    for topic in sorted(features[category]):
        for value in sorted(features[category][topic]):
            n = features[category][topic][value]
            lines.append( "%4d;%s;%s;%s" % (n, category, topic, value) )

for line in reversed(sorted(lines)):
    print line
# Out:
# 6907;First Party Collection/Use;Does/Does Not;Does
# 4600;First Party Collection/Use;User Type;Unspecified
# 4106;First Party Collection/Use;Choice Scope;Unspecified
# 3878;First Party Collection/Use;Choice Type;Unspecified
# 3841;Third Party Sharing/Collection;Does/Does Not;Does
# 3278;First Party Collection/Use;Identifiability;Unspecified
# 2912;First Party Collection/Use;Action First-Party;Unspecified
# 2896;Third Party Sharing/Collection;User Type;Unspecified
# 2706;Third Party Sharing/Collection;Action Third Party;Receive/Shared with
# 2698;First Party Collection/Use;Action First-Party;Collect on website
# 2546;Third Party Sharing/Collection;Choice Scope;Unspecified
# 2407;Third Party Sharing/Collection;Choice Type;Unspecified
# 2095;First Party Collection/Use;Purpose;Unspecified
# 1980;First Party Collection/Use;Choice Scope;not-selected
# 1963;Third Party Sharing/Collection;Identifiability;Unspecified
# 1939;First Party Collection/Use;Collection Mode;Unspecified
# 1933;Third Party Sharing/Collection;Third Party Entity;Unnamed third party
# 1907;First Party Collection/Use;Identifiability;not-selected
# 1903;First Party Collection/Use;User Type;not-selected
# 1883;First Party Collection/Use;Collection Mode;Implicit
# 1751;First Party Collection/Use;Collection Mode;not-selected
# 1712;First Party Collection/Use;Choice Type;not-selected
# 1562;First Party Collection/Use;Collection Mode;Explicit
# 1501;First Party Collection/Use;Personal Information Type;Unspecified
# 1277;Third Party Sharing/Collection;Personal Information Type;Unspecified
# 1209;Third Party Sharing/Collection;Third Party Entity;Named third party
# 1134;First Party Collection/Use;Identifiability;Identifiable
# 1117;Third Party Sharing/Collection;Choice Scope;not-selected
# 1074;Third Party Sharing/Collection;User Type;not-selected
# 1048;Third Party Sharing/Collection;Personal Information Type;Generic personal information
# 1036;Third Party Sharing/Collection;Identifiability;not-selected
# 1031;Third Party Sharing/Collection;Purpose;Unspecified
# 1022;First Party Collection/Use;Purpose;Basic service/feature
#  957;First Party Collection/Use;Purpose;Analytics/Research
#  919;First Party Collection/Use;Personal Information Type;Generic personal information
#  905;User Choice/Control;User Type;Unspecified
#  900;First Party Collection/Use;Personal Information Type;Cookies and tracking elements
#  898;Third Party Sharing/Collection;Choice Type;not-selected
#  794;First Party Collection/Use;Personal Information Type;Contact
#  771;First Party Collection/Use;Choice Scope;Collection
#  751;First Party Collection/Use;Purpose;Additional service/feature
#  679;Third Party Sharing/Collection;Purpose;Advertising
#  678;Other;Other Type;Introductory/Generic
#  678;First Party Collection/Use;Choice Type;Opt-in
#  673;First Party Collection/Use;Identifiability;Aggregated or anonymized
#  643;First Party Collection/Use;Personal Information Type;User online activities
#  627;Third Party Sharing/Collection;Identifiability;Identifiable
#  605;First Party Collection/Use;Action First-Party;Other
#  590;Other;Other Type;Practice not covered
#  544;First Party Collection/Use;Purpose;Personalization/Customization
#  516;User Choice/Control;Purpose;Unspecified
#  514;User Choice/Control;Personal Information Type;Unspecified
#  513;First Party Collection/Use;Purpose;Advertising
#  505;First Party Collection/Use;Purpose;Marketing
#  494;User Choice/Control;Choice Scope;First party use
#  493;Other;Other Type;Other
#  485;Third Party Sharing/Collection;Identifiability;Aggregated or anonymized
#  472;First Party Collection/Use;Personal Information Type;IP address and device IDs
#  445;Third Party Sharing/Collection;Third Party Entity;Unspecified
#  442;First Party Collection/Use;Purpose;Service Operation and Security
#  410;Third Party Sharing/Collection;Purpose;Basic service/feature
#  404;First Party Collection/Use;User Type;User with account
#  391;Third Party Sharing/Collection;Choice Type;Opt-in
#  378;User Choice/Control;Purpose;Marketing
#  377;First Party Collection/Use;Choice Type;Dont use service/feature
#  369;Third Party Sharing/Collection;Action Third Party;Track on first party website/app
#  367;Third Party Sharing/Collection;Purpose;Additional service/feature
#  366;Other;Other Type;Privacy contact information
#  361;Third Party Sharing/Collection;Personal Information Type;Cookies and tracking elements
#  359;Third Party Sharing/Collection;Action Third Party;Collect on first party website/app
#  358;User Choice/Control;User Type;not-selected
#  355;First Party Collection/Use;Personal Information Type;Computer information
#  342;User Choice/Control;Choice Scope;Unspecified
#  337;Third Party Sharing/Collection;Personal Information Type;User online activities
#  327;Third Party Sharing/Collection;Purpose;Service operation and security
#  327;First Party Collection/Use;Personal Information Type;Location
#  321;Third Party Sharing/Collection;Third Party Entity;Other part of company/affiliate
#  319;Third Party Sharing/Collection;Does/Does Not;Does Not
#  318;Third Party Sharing/Collection;Purpose;Marketing
#  310;Third Party Sharing/Collection;Purpose;Legal requirement
#  310;Third Party Sharing/Collection;Purpose;Analytics/Research
#  304;User Choice/Control;Personal Information Type;Contact
#  294;First Party Collection/Use;Personal Information Type;Demographic
#  293;First Party Collection/Use;Action First-Party;Receive from other service/third-party (unnamed)
#  291;Third Party Sharing/Collection;Action Third Party;Unspecified
#  284;User Access, Edit and Deletion;Access Type;Edit information
#  280;Third Party Sharing/Collection;Action Third Party;Other
#  280;Policy Change;User Choice;Unspecified
#  258;International and Specific Audiences;Audience Type;Children
#  257;First Party Collection/Use;Personal Information Type;Financial
#  253;User Choice/Control;Choice Scope;First party collection
#  253;Third Party Sharing/Collection;Personal Information Type;Contact
#  252;User Choice/Control;Choice Scope;Third party sharing/collection
#  252;First Party Collection/Use;Personal Information Type;Other
#  247;User Access, Edit and Deletion;User Type;Unspecified
#  247;First Party Collection/Use;Action First-Party;Collect in mobile app
#  238;User Choice/Control;Choice Type;Opt-out link
#  235;Third Party Sharing/Collection;Choice Scope;Collection
#  231;User Access, Edit and Deletion;Access Scope;User account data
#  228;First Party Collection/Use;Does/Does Not;Does Not
#  224;User Choice/Control;Personal Information Type;Cookies and tracking elements
#  219;User Choice/Control;Choice Type;Opt-out via contacting company
#  219;User Choice/Control;Choice Type;Opt-in
#  218;Data Security;Security Measure;Generic
#  210;First Party Collection/Use;Purpose;Other
#  207;First Party Collection/Use;Choice Type;Browser/device privacy controls
#  205;Policy Change;Change Type;Unspecified
#  204;User Choice/Control;Choice Type;Browser/device privacy controls
#  200;User Access, Edit and Deletion;User Type;User with account
#  198;Third Party Sharing/Collection;Choice Scope;Use
#  194;User Choice/Control;Purpose;Advertising
#  193;User Access, Edit and Deletion;Access Scope;Unspecified
#  193;Third Party Sharing/Collection;Purpose;Merger/Acquisition
#  182;First Party Collection/Use;Choice Scope;Use
#  177;User Choice/Control;Personal Information Type;Generic personal information
#  162;User Choice/Control;Choice Type;Unspecified
#  155;Third Party Sharing/Collection;Personal Information Type;Other
#  155;Third Party Sharing/Collection;Action Third Party;See
#  155;First Party Collection/Use;User Type;Other
#  150;Third Party Sharing/Collection;Purpose;Other
#  150;First Party Collection/Use;Personal Information Type;User profile
#  150;First Party Collection/Use;Action First-Party;Receive from other service/third-party (named)
#  148;Data Retention;Retention Period;Unspecified
#  143;First Party Collection/Use;Identifiability;Other
#  142;User Choice/Control;User Type;User with account
#  142;Policy Change;Change Type;Privacy relevant change
#  130;Policy Change;Notification Type;General notice in privacy policy
#  128;Third Party Sharing/Collection;Personal Information Type;IP address and device IDs
#  123;User Choice/Control;Choice Type;Dont use service/feature
#  120;User Choice/Control;Purpose;Basic service/feature
#  120;Third Party Sharing/Collection;User Type;User with account
#  117;User Choice/Control;Choice Scope;Third party use
#  116;Third Party Sharing/Collection;Personal Information Type;Financial
#  114;User Access, Edit and Deletion;User Type;not-selected
#  113;Third Party Sharing/Collection;Third Party Entity;Public
#  109;User Choice/Control;Choice Type;Other
#  109;User Choice/Control;Choice Type;First-party privacy controls
#  107;International and Specific Audiences;Audience Type;Californians
#  106;User Choice/Control;Purpose;Additional service/feature
#  106;Third Party Sharing/Collection;Personal Information Type;Health
#  103;First Party Collection/Use;Choice Type;Other
#  103;Data Retention;Retention Purpose;Unspecified
#  102;Third Party Sharing/Collection;Personal Information Type;Computer information
#   98;User Access, Edit and Deletion;Access Type;View
#   97;Third Party Sharing/Collection;Personal Information Type;User Profile
#   96;First Party Collection/Use;Choice Scope;Both
#   95;Third Party Sharing/Collection;Choice Type;Dont use service/feature
#   92;First Party Collection/Use;Action First-Party;Track user on other websites
#   92;Data Security;Security Measure;Other
#   90;Third Party Sharing/Collection;Choice Type;Opt-out link
#   87;First Party Collection/Use;Purpose;Legal requirement
#   87;Data Retention;Personal Information Type;Unspecified
#   84;Data Security;Security Measure;Data access limitation
#   78;First Party Collection/Use;Personal Information Type;Health
#   77;Third Party Sharing/Collection;Choice Type;Opt-out via contacting company
#   77;Policy Change;Notification Type;General notice on website
#   76;Third Party Sharing/Collection;Choice Type;Third-party privacy controls
#   75;User Choice/Control;Choice Type;Third-party privacy controls
#   75;Data Retention;Retention Purpose;Perform service
#   74;Policy Change;Notification Type;Personal notice
#   73;First Party Collection/Use;User Type;User without account
#   72;International and Specific Audiences;Audience Type;Citizens from other countries
#   72;Data Retention;Retention Period;Limited
#   71;Third Party Sharing/Collection;Third Party Entity;Other
#   71;Data Security;Security Measure;Secure data transfer
#   69;Third Party Sharing/Collection;Personal Information Type;Location
#   69;First Party Collection/Use;Personal Information Type;Personal identifier
#   68;Third Party Sharing/Collection;Third Party Entity;Other users
#   68;Policy Change;Notification Type;Unspecified
#   67;First Party Collection/Use;Personal Information Type;Social media data
#   66;First Party Collection/Use;Action First-Party;Collect from user on other websites
#   65;Third Party Sharing/Collection;Purpose;Personalization/Customization
#   64;User Access, Edit and Deletion;Access Type;Delete account (partial)
#   64;Third Party Sharing/Collection;Personal Information Type;Demographic
#   64;Third Party Sharing/Collection;Choice Scope;Both
#   63;First Party Collection/Use;Choice Type;Opt-out link
#   62;User Access, Edit and Deletion;Access Type;Other
#   58;User Choice/Control;Personal Information Type;Other
#   58;Third Party Sharing/Collection;Choice Type;Other
#   57;User Access, Edit and Deletion;Access Scope;Profile data
#   57;Third Party Sharing/Collection;User Type;Other
#   57;First Party Collection/Use;Personal Information Type;Survey data
#   54;User Choice/Control;Purpose;Other
#   54;Data Retention;Personal Information Type;Generic personal information
#   50;First Party Collection/Use;Choice Type;Third-party privacy controls
#   49;Third Party Sharing/Collection;Identifiability;Other
#   46;User Access, Edit and Deletion;Access Scope;Other data about user
#   43;User Choice/Control;Personal Information Type;User online activities
#   42;First Party Collection/Use;Action First-Party;Receive from other parts of company/affiliates
#   41;User Access, Edit and Deletion;Access Scope;Other
#   40;Data Security;Security Measure;Privacy/Security program
#   38;Third Party Sharing/Collection;Choice Type;Browser/device privacy controls
#   38;First Party Collection/Use;Choice Type;Opt-out via contacting company
#   38;Do Not Track;Do Not Track policy;Not honored
#   37;User Choice/Control;Purpose;Personalization/Customization
#   36;User Choice/Control;Personal Information Type;Health
#   36;International and Specific Audiences;Audience Type;Europeans
#   35;User Choice/Control;User Type;Other
#   35;Policy Change;User Choice;None
#   34;User Access, Edit and Deletion;Access Type;Unspecified
#   34;Policy Change;User Choice;User participation
#   34;Data Retention;Retention Purpose;Legal requirement
#   31;Data Security;Security Measure;Secure data storage
#   30;Third Party Sharing/Collection;Choice Type;First-party privacy controls
#   30;First Party Collection/Use;Action First-Party;Collect on mobile website
#   30;Data Retention;Retention Period;Stated Period
#   30;Data Retention;Personal Information Type;Contact
#   29;First Party Collection/Use;Choice Type;First-party privacy controls
#   29;Data Retention;Retention Purpose;Service operation and security
#   28;User Choice/Control;Personal Information Type;Location
#   28;International and Specific Audiences;Audience Type;Other
#   27;User Choice/Control;Personal Information Type;User profile
#   27;Data Security;Security Measure;Secure user authentication
#   25;User Access, Edit and Deletion;Access Type;Delete account (full)
#   25;Data Retention;Personal Information Type;Other
#   24;User Access, Edit and Deletion;Access Scope;Transactional data
#   24;Third Party Sharing/Collection;Personal Information Type;Survey data
#   23;User Access, Edit and Deletion;User Type;Other
#   23;Third Party Sharing/Collection;Personal Information Type;Personal identifier
#   23;Data Security;Security Measure;Privacy review/audit
#   22;Policy Change;Notification Type;Other
#   22;Data Retention;Retention Purpose;Other
#   22;Data Retention;Personal Information Type;Cookies and tracking elements
#   21;Data Retention;Retention Period;Indefinitely
#   19;User Choice/Control;Purpose;Service Operation and Security
#   19;Policy Change;User Choice;Opt-in
#   19;Data Retention;Personal Information Type;User online activities
#   18;User Choice/Control;User Type;User without account
#   18;Data Retention;Retention Period;Other
#   17;User Choice/Control;Purpose;Legal requirement
#   17;Data Retention;Personal Information Type;IP address and device IDs
#   16;User Access, Edit and Deletion;Access Type;Deactivate account
#   16;Policy Change;Change Type;Non-privacy relevant change
#   16;Data Retention;Retention Purpose;Analytics/Research
#   15;Policy Change;Change Type;In case of merger or acquisition
#   14;User Choice/Control;Purpose;Analytics/Research
#   13;Third Party Sharing/Collection;User Type;User without account
#   12;User Choice/Control;Personal Information Type;Demographic
#   12;Policy Change;Notification Type;No notification
#   11;User Choice/Control;Personal Information Type;Personal identifier
#   11;Data Retention;Personal Information Type;Financial
#   10;User Choice/Control;Personal Information Type;Financial
#   10;Data Security;Security Measure;Unspecified
#   10;Data Retention;Personal Information Type;User profile
#    9;First Party Collection/Use;Purpose;Merger/Acquisition
#    8;User Access, Edit and Deletion;User Type;User without account
#    8;User Access, Edit and Deletion;Access Type;None
#    8;Policy Change;User Choice;Other
#    7;Policy Change;User Choice;Opt-out
#    6;User Choice/Control;Personal Information Type;Social media data
#    6;Data Security;Security Measure;Privacy training
#    6;Data Retention;Retention Purpose;Marketing
#    5;User Choice/Control;Personal Information Type;Computer information
#    5;Policy Change;Change Type;Other
#    5;Data Retention;Personal Information Type;Computer information
#    4;Data Retention;Retention Purpose;Advertising
#    3;User Choice/Control;Purpose;Merger/Acquisition
#    3;Do Not Track;Do Not Track policy;Mentioned, but unclear if honored
#    3;Data Retention;Personal Information Type;Personal identifier
#    2;User Choice/Control;Personal Information Type;Survey data
#    2;Do Not Track;Do Not Track policy;Other
#    2;Data Retention;Personal Information Type;Social media data
#    2;Data Retention;Personal Information Type;Location
#    1;User Choice/Control;Personal Information Type;IP address and device IDs
#    1;User Access, Edit and Deletion;Access Type;Export
#    1;Do Not Track;Do Not Track policy;Honored
#    1;Data Retention;Personal Information Type;Health
#    1;Data Retention;Personal Information Type;Demographic

# %% [markdown]
# ### Read in feature map
# Map category, topic, and value to a label

# %%
feature_map_file = pd.read_csv("Data/label_map.csv", header=0, sep=",")
feature_map = {}

for row in feature_map_file.iterrows():
    index, rowdata = row
    
    category = rowdata["Category"]
    topic = rowdata["Topic"]
    value = rowdata["Value"]
    label = rowdata["Label"]
    n = rowdata["n"]

    # only consider features with at least 100 classifications
    if n < 100:
        continue
    
    if category not in feature_map:
        feature_map[category] = {}

    if topic not in feature_map[category]:
        feature_map[category][topic] = {}
    
    if value not in feature_map[category][topic]:
        feature_map[category][topic][value] = {}

    feature_map[category][topic][value] = label

feature_map_file.head(3)
# Out:
#          Category                      Topic                          Value  \
# 0  Data Retention  Personal Information Type           Computer information
# 1  Data Retention  Personal Information Type                        Contact
# 2  Data Retention  Personal Information Type  Cookies and tracking elements
#
#             Label   n
# 0  Data Retention   5
# 1  Data Retention  30
# 2  Data Retention  22

# %% [markdown]
# ### Use the feature map to label data

# %%
labels = set()
labeled_data = []

for site in data:
    for category in data[site]:
        for topic in data[site][category]:
            for row in data[site][category][topic].iterrows():
                index, rowdata = row
                
                try:
                    value = rowdata["value"]
                    selectedText = rowdata["selectedText"]
                    if selectedText.lower() == "nan":
                        continue
                except KeyError:
                    continue
                except AttributeError:
                    continue
                    
                try:
                    label = feature_map[category][topic][value]
                except:
                    # if we could not find a label, skip it
                    continue
                    
                if label == "-":
                    continue
                
                labels.add(label)
                labeled_data.append((selectedText, label))

print "Length of labeled data: %d" % (len(labeled_data))
print "Number of labels: %d" % (len(labels))
print "Labels: %s" % ("; ".join(labels))
# Out:
# Length of labeled data: 76165
# Number of labels: 9
# Labels: Data Retention; First Party Collection/Use; Policy Change; International and Specific Audiences; User Access, Edit and Deletion; User Choice/Control; Data Security; Third Party Sharing/Collection; Other

# %% [markdown]
# ### Print a few labels with selectedText

# %%
for text, label in labeled_data[:10]:
    print "%s: %s" % (label, text)
# Out:
# Data Retention: eparately from any account information that directly identifies the user, such as name, e-mail address, or phone numbers.
# Data Retention: which are retained
# Data Retention: retained
# Data Retention: We store search terms (and the cookie IDs associated with search terms) separately from any account information that directly identifies the user, such as name, e-mail address, or phone numbers. We have technological safeguards in place designed to prevent the unauthorized correlation of this data and we remove the entirety of the IP address after 6 months, cookies and other cross session identifiers, after 18 months.
# Data Retention: separately from any account information that directly identifies the user, such as name, e-mail address, or phone numbers.
# Data Retention: nformation from our standard search logs, which are retained and anonymized as described in the Collecting Your Information Section.
# First Party Collection/Use: If you sign into
# First Party Collection/Use: If you sign into Bing or other Microsoft services using a Microsoft account, we will set or read one or more additional cookies.
# First Party Collection/Use: If you sign into Bing or other Microsoft services using a Microsoft account, we will set or read one or more additional cookies.
# First Party Collection/Use: When you use Bing and MSN services with a web browser, we will place one or more "cookies" on your machine.
